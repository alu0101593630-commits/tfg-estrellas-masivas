    "HD46300": "A0 Ib", "HD87737": "A0 Ib", "HD123299": "A0 III", "HD103287": "A0 V",
    "HD172167": "A0 V", "HD197345": "A2 Ia"
}

def graficar_comparativa():
    print("\n" + "="*40)
    print("   VISUALIZADOR DE ESPECTROS (ORDENADO)")
    print("="*40)
    
    entrada = input("Estrellas a comparar (ej: 2083, 2085, 2100): ")
    if not entrada.strip(): return
    
    estrellas = [e.strip().upper() for e in entrada.split(',')]
    estrellas = [e if e.startswith("HD") else f"HD{e}" for e in estrellas]

    incremento_offset = 1.0
    fig, (ax_blue, ax_red) = plt.subplots(2, 1, figsize=(14, 12))
    
    estrellas_para_graficar = estrellas[::-1]
    offset = 0.0
    hay_datos = False

    for star in estrellas_para_graficar:
        archivo_blue = carpeta_resultados / f"{star}_blue.csv"
        archivo_red = carpeta_resultados / f"{star}_red.csv"
        
        # Buscamos el tipo espectral en el diccionario. Si no está, ponemos "SpC Desconocido"
        tipo_espectral = DATA_ESPECTRAL.get(star, "SpC ?")
        etiqueta = f"{star} ({tipo_espectral})"
        
        linea_color = None 

        # --- DIBUJAR BLUE ---
        if archivo_blue.exists():
            df_b = pd.read_csv(archivo_blue)
            linea = ax_blue.plot(df_b['longitud_onda'], df_b['flujo_normalizado'] + offset, label=etiqueta, lw=1.2)
            linea_color = linea[0].get_color()
            hay_datos = True
        else:
            print(f"❌ No existe BLUE para {star}")

        # --- DIBUJAR RED ---
        if archivo_red.exists():
            df_r = pd.read_csv(archivo_red)
            ax_red.plot(df_r['longitud_onda'], df_r['flujo_normalizado'] + offset, label=etiqueta, lw=1.2, color=linea_color)

        offset += incremento_offset

    if not hay_datos:
        print("⚠️ No hay datos para mostrar.")
        plt.close()
        return

    # --- LEYENDA SINCRONIZADA ---
    for ax in [ax_blue, ax_red]:
        handles, labels = ax.get_legend_handles_labels()
        ax.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)

    ax_blue.set_title("Región BLUE", fontsize=14, fontweight='bold')
    ax_blue.set_ylabel("Flujo Normalizado + Offset")
    ax_blue.grid(True, alpha=0.2)

    ax_red.set_title("Región RED", fontsize=14, fontweight='bold')
    ax_red.set_xlabel("Longitud de Onda (Å)")
    ax_red.set_ylabel("Flujo Normalizado + Offset")
    ax_red.grid(True, alpha=0.2)

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    while True:
        graficar_comparativa()
        if input("\n¿Hacer otra comparativa? (s/n): ").lower() != 's':
            break
# Out:
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
# ========================================
#    VISUALIZADOR DE ESPECTROS (ORDENADO)
# ========================================
